# %%
import os
os.chdir("/Workspace/Users/haoqiwu@emea.corpdir.net/AsymDSD")

# %%
# %pip install -r requirements.txt
# %pip install opencv-python-headless==4.12.0.88

# %%
# %pip install "git+https://github.com/facebookresearch/pytorch3d.git" --no-build-isolation

# %%
# %pip install -e .

# %%
import wandb

wandb.login(key="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")

# %%
# %sh
mkdir -p /local_disk0/dataset/parts_no_trace/npz

# Copy all split zip parts
cp /Volumes/westeurope_extollo_rd_eu_rd_k_data_analytics_adbv/rd_k_warehouse/rd_k_katalog/data/npz.z* \
   /local_disk0/dataset/parts_no_trace/

cp /Volumes/westeurope_extollo_rd_eu_rd_k_data_analytics_adbv/rd_k_warehouse/rd_k_katalog/data/npz.zip \
   /local_disk0/dataset/parts_no_trace/

echo "Copy done"

cd /local_disk0/dataset/parts_no_trace/

# Rebuild split archive into one zip
zip -s 0 npz.zip --out npz_full.zip

# Unzip into npz folder
unzip npz_full.zip -d /local_disk0/dataset/parts_no_trace/

echo "Unzip done"

# %%
# %sh
export CUDA_MATMUL_TF32='high'
export LOG_LEVEL='INFO'
export WARNING_LOG_FILE='train.err'

python ./asymdsd/run/ssrl_pqstem_fab_packed_cli.py fit --config configs/ssrl/ex_ssrl_pqstem_fab_packed.yaml
